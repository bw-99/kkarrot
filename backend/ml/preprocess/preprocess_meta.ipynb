# %%
import pandas as pd
import numpy as np

meta_df = pd.read_pickle("../../data/interim/item_meta.pkl")
meta_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 meta_df = pd.read_pickle("../../data/raw/item_meta.pkl")
#       5 meta_df
#
# File ~/anaconda3/envs/fyi_39/lib/python3.9/site-packages/pandas/io/pickle.py:189, in read_pickle(filepath_or_buffer, compression, storage_options)
#     125 """
#     126 Load pickled pandas object (or any object) from file.
#     127
#    (...)
#     186 4    4    9
#     187 """
#     188 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 189 with get_handle(
#     190     filepath_or_buffer,
#     191     "rb",
#     192     compression=compression,
#     193     is_text=False,
#     194     storage_options=storage_options,
#     195 ) as handles:
#     196     # 1) try standard library Pickle
#     197     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     198     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     200     try:
#     201         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     202         try:
#
# File ~/anaconda3/envs/fyi_39/lib/python3.9/site-packages/pandas/io/common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/raw/item_meta.pkl'

# %%
rating_df = pd.read_pickle("../../data/interim/rating.pkl")[["item_id", "parent_asin"]]
rating_df= rating_df.drop_duplicates()
rating_df
# Out:
#     item_id parent_asin
# 0     28833  B01G15TGCU
# 0     29361  B01HRPJQ2S
# 0     32319  B06XQYN77L
# 0     37990  B07F9SG3RX
# 0     40014  B07L4GYFK9
# ..      ...         ...
# 999   42021  B07RNMKJ6B
# 999   42245  B07S4BKMZV
# 999   42690  B07TBGVLBH
# 999   50815  B08QLWTC2M
# 999   65242  B0BJWBC4SK
#
# [72319 rows x 2 columns]

# %%
rating_df.iloc[:10].to_json(orient="records")
# Out:
# '[{"item_id":28833,"parent_asin":"B01G15TGCU"},{"item_id":29361,"parent_asin":"B01HRPJQ2S"},{"item_id":32319,"parent_asin":"B06XQYN77L"},{"item_id":37990,"parent_asin":"B07F9SG3RX"},{"item_id":40014,"parent_asin":"B07L4GYFK9"},{"item_id":40697,"parent_asin":"B07NNXLYHC"},{"item_id":41653,"parent_asin":"B07QQRXK3T"},{"item_id":44799,"parent_asin":"B0814LJYJ2"},{"item_id":48383,"parent_asin":"B08DR4YZ2Z"},{"item_id":48899,"parent_asin":"B08GMDQ87T"}]'

# %%
meta_df = pd.merge(rating_df, meta_df, how="inner", on="parent_asin")
meta_df
# Out:
#       item_id parent_asin                                              title  \
# 0       28833  B01G15TGCU  KAMISAFE SD/TF Memory Card Case Holder Protect...
# 1       29361  B01HRPJQ2S  Panasonic Sports Clip Earbud Headphones RP-HS3...
# 2       32319  B06XQYN77L  BESIGN Bluetooth Ground Loop Noise Isolator fo...
# 3       37990  B07F9SG3RX  Powerextra 4x Zipper Lens Case Lens Pouch Bag ...
# 4       40014  B07L4GYFK9  mucro Sports Headphones Wired Earbuds with Mic...
# ...       ...         ...                                                ...
# 72314   42021  B07RNMKJ6B  Steiner BluHorizons Binoculars - Unique Lens T...
# 72315   42245  B07S4BKMZV  Lenovo Flex 14 2-in-1 Convertible Laptop, 14 I...
# 72316   42690  B07TBGVLBH       Pioneer VSX-LX504 9.2-ch Network AV Receiver
# 72317   50815  B08QLWTC2M  Definitive Technology ProCenter 2000 Compact C...
# 72318   65242  B0BJWBC4SK  Ergotron – Notebook Tray – for Laptop, Noteboo...
#
#                                               categories  \
# 0      [Electronics, Computers & Accessories, Compute...
# 1      [Electronics, Headphones, Earbuds & Accessorie...
# 2      [Electronics, Car & Vehicle Electronics, Vehic...
# 3      [Electronics, Camera & Photo, Bags & Cases, Le...
# 4      [Electronics, Headphones, Earbuds & Accessorie...
# ...                                                  ...
# 72314  [Electronics, Camera & Photo, Binoculars & Sco...
# 72315  [Electronics, Computers & Accessories, Compute...
# 72316  [Electronics, Home Audio, Home Theater, Receiv...
# 72317  [Electronics, Home Audio, Speakers, Center-Cha...
# 72318  [Electronics, Computers & Accessories, Compute...
#
#               main_category  average_rating  \
# 0                 Computers             3.7
# 1      Home Audio & Theater             4.3
# 2           All Electronics             4.4
# 3                      None             4.4
# 4           All Electronics             3.8
# ...                     ...             ...
# 72314     Sports & Outdoors             4.4
# 72315             Computers             4.2
# 72316       All Electronics             3.9
# 72317  Home Audio & Theater             4.7
# 72318             Computers             4.4
#
#                                              description  \
# 0                                                     []
# 1      [The Panasonic RP-HS34 Water Resistant Sport C...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 72314                                                 []
# 72315  [Meet the Lenovo flex 14, a stylishly compact ...
# 72316  [The Elite vsx-lx504 creates the soundscape of...
# 72317  [Product Description, The compact and versatil...
# 72318  [Add this accessory to an LCD arm or pivot and...
#
#                                                   images   price  \
# 0      {'hi_res': ['https://m.media-amazon.com/images...    None
# 1      {'hi_res': ['https://m.media-amazon.com/images...    None
# 2      {'hi_res': ['https://m.media-amazon.com/images...    9.99
# 3      {'hi_res': ['https://m.media-amazon.com/images...   23.99
# 4      {'hi_res': ['https://m.media-amazon.com/images...   18.99
# ...                                                  ...     ...
# 72314  {'hi_res': ['https://m.media-amazon.com/images...  215.99
# 72315  {'hi_res': ['https://m.media-amazon.com/images...    None
# 72316  {'hi_res': ['https://m.media-amazon.com/images...    None
# 72317  {'hi_res': ['https://m.media-amazon.com/images...   379.0
# 72318  {'hi_res': ['https://m.media-amazon.com/images...    61.0
#
#        rating_number
# 0                 41
# 1               7923
# 2               5619
# 3               1311
# 4               3363
# ...              ...
# 72314            371
# 72315             57
# 72316             34
# 72317            192
# 72318            362
#
# [72319 rows x 10 columns]

# %%
meta_df = meta_df.sort_values("rating_number", ascending=False)
meta_df
# Out:
#       item_id parent_asin                                              title  \
# 4311    38864  B07H65KP63  Echo Dot (3rd Gen, 2018 release) - Smart speak...
# 272     38754  B07GZFM1ZM  Fire TV Stick 4K streaming device with Alexa V...
# 7178    41262  B07PXGQC1Q  Apple AirPods (2nd Generation) Wireless Earbud...
# 7638    48454  B08F1P3BCC  Echo Dot (4th Gen) | Smart speaker with Alexa ...
# 8306    39927  B07KTYJ769  Amazon Smart Plug, for home automation, Works ...
# ...       ...         ...                                                ...
# 23452   45138  B0822S9RX4    IBM Boldface PS Cartridge Printwheel ll 1353504
# 26832   52322  B08ZJFBXQL  JYH 1200Mbps WiFi Extender, 2.4 & 5GHz Dual Ba...
# 12733   19042  B00JQ1V78I                                         TaoTronics
# 12650   37900  B07F3KN83F  TIEGEM USB Type C 3.1 Gen 2 Cable (100W/10Gbps...
# 44672   36427  B07BLLTLNP  MegaGear ''Ultra Light'' Neoprene Camera Case ...
#
#                                               categories  \
# 4311                                                  []
# 272                                                   []
# 7178                                                  []
# 7638                                                  []
# 8306                                                  []
# ...                                                  ...
# 23452             [Electronics, Computers & Accessories]
# 26832  [Electronics, Computers & Accessories, Network...
# 12733  [Electronics, Headphones, Earbuds & Accessorie...
# 12650  [Electronics, Computers & Accessories, Compute...
# 44672  [Electronics, Camera & Photo, Bags & Cases, Ca...
#
#                    main_category  average_rating  \
# 4311              Amazon Devices             4.7
# 272               Amazon Devices             4.7
# 7178              Apple Products             4.7
# 7638              Amazon Devices             4.7
# 8306              Amazon Devices             4.7
# ...                          ...             ...
# 23452            Office Products             5.0
# 26832            All Electronics             5.0
# 12733  Cell Phones & Accessories             1.0
# 12650    Industrial & Scientific             5.0
# 44672             Camera & Photo             4.0
#
#                                              description  \
# 4311                                                  []
# 272                                                   []
# 7178                                                  []
# 7638                                                  []
# 8306                                                  []
# ...                                                  ...
# 23452                                   [|SS-TW-PW-FBM|]
# 26832                                                 []
# 12733                                                 []
# 12650                                                 []
# 44672  [MegaGear Ultra Light Neoprene Camera Cases ar...
#
#                                                   images  price  rating_number
# 4311   {'hi_res': ['https://m.media-amazon.com/images...   None        1034896
# 272    {'hi_res': ['https://m.media-amazon.com/images...   None         819630
# 7178   {'hi_res': ['https://m.media-amazon.com/images...   99.0         585624
# 7638   {'hi_res': ['https://m.media-amazon.com/images...   None         584328
# 8306   {'hi_res': ['https://m.media-amazon.com/images...  24.99         542825
# ...                                                  ...    ...            ...
# 23452  {'hi_res': ['https://m.media-amazon.com/images...  99.99              1
# 26832  {'hi_res': ['https://m.media-amazon.com/images...   None              1
# 12733  {'hi_res': ['https://m.media-amazon.com/images...   None              1
# 12650  {'hi_res': ['https://m.media-amazon.com/images...   None              1
# 44672  {'hi_res': ['https://m.media-amazon.com/images...   None              1
#
# [72319 rows x 10 columns]

# %%
meta_df.to_pickle("../../data/processed/item_meta.pkl")
