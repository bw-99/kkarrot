# %%
import pandas as pd
import numpy as np

meta_df = pd.read_pickle("../../data/interim/item_meta.pkl")
meta_df
# Out:
#                                                     title  \
# 0                  FS-1051 FATSHARK TELEPORTER V3 HEADSET
# 1       Digi-Tatoo Decal Skin Compatible With MacBook ...
# 2       NotoCity Compatible with Vivoactive 4 band 22m...
# 3                  Motorola Droid X Essentials Combo Pack
# 4       Raymarine Wi-Fish DownVision Blackbox Sonar wi...
# ...                                                   ...
# 368223  HBT Waterproof Airtag Holder/AirTag Keychain C...
# 368224  Monster N-Lite Clear Talk Wireless Earbuds Blu...
# 368225  [Apple MFi Certified] Coiled Lightning Cable f...
# 368226  trueCABLE Cat6 Plenum (CMP), 1000ft, Green, 23...
# 368227  Lekaby Wireless Earbuds Bluetooth 5.3 Headphon...
#
#                                                categories  \
# 0        [Electronics, Television & Video, Video Glasses]
# 1       [Electronics, Computers & Accessories, Laptop ...
# 2       [Electronics, Wearable Technology, Clips, Arm ...
# 3       [Electronics, Computers & Accessories, Compute...
# 4       [Electronics, Car & Vehicle Electronics, Marin...
# ...                                                   ...
# 368223  [Electronics, Headphones, Earbuds & Accessorie...
# 368224  [Electronics, Headphones, Earbuds & Accessorie...
# 368225  [Electronics, Computers & Accessories, Compute...
# 368226  [Electronics, Computers & Accessories, Compute...
# 368227  [Electronics, Headphones, Earbuds & Accessorie...
#
#                     main_category  average_rating  \
# 0                 All Electronics             3.5
# 1                       Computers             4.5
# 2                  AMAZON FASHION             4.5
# 3       Cell Phones & Accessories             3.8
# 4               Sports & Outdoors             3.5
# ...                           ...             ...
# 368223                       None             4.4
# 368224                       None             4.2
# 368225    Industrial & Scientific             4.2
# 368226    Industrial & Scientific             4.5
# 368227            All Electronics             5.0
#
#                                               description  \
# 0       [Teleporter V3 The “Teleporter V3” kit sets a ...
# 1                                                      []
# 2                                                      []
# 3       [all Genuine High Quality Motorola Made Access...
# 4       [Transform your smartphone into a powerful CHI...
# ...                                                   ...
# 368223                                                 []
# 368224                                                 []
# 368225  [Coiled Apple Carplay Cable,3ft Coiled Lightni...
# 368226                                                 []
# 368227                                                 []
#
#                                                    images   price parent_asin  \
# 0       {'hi_res': [None], 'large': ['https://m.media-...    None  B00MCW7G9M
# 1       {'hi_res': ['https://m.media-amazon.com/images...   19.99  B07SM135LS
# 2       {'hi_res': ['https://m.media-amazon.com/images...    9.99  B089CNGZCW
# 3       {'hi_res': [None, None, None, None, None], 'la...   14.99  B004E2Z88O
# 4       {'hi_res': ['https://m.media-amazon.com/images...    None  B00TX536EK
# ...                                                   ...     ...         ...
# 368223  {'hi_res': ['https://m.media-amazon.com/images...   25.99  B0BHVHQ6NR
# 368224  {'hi_res': ['https://m.media-amazon.com/images...   39.99  B0BHSP7BGD
# 368225  {'hi_res': ['https://m.media-amazon.com/images...    8.99  B0CGHG8Y7H
# 368226  {'hi_res': ['https://m.media-amazon.com/images...  318.99  B0C24HF7P4
# 368227  {'hi_res': ['https://m.media-amazon.com/images...    None  B0BZ8K2LJX
#
#         rating_number
# 0                   6
# 1                 246
# 2                 233
# 3                  64
# 4                  25
# ...               ...
# 368223             66
# 368224            125
# 368225            148
# 368226            131
# 368227            162
#
# [368228 rows x 9 columns]

# %%
rating_df = pd.read_pickle("../../data/interim/rating.pkl")[["item_id", "parent_asin"]]
rating_df= rating_df.drop_duplicates()
rating_df
# Out:
#      item_id parent_asin
# 0        556  B00006HVLW
# 0        843  B00009R6NZ
# 0       1039  B0000BZL05
# 0       3865  B000SAKX90
# 0       4646  B00139XOCI
# ...      ...         ...
# 1998   60182  B07S4BKMZV
# 1998   60806  B07TBGVLBH
# 1998   71289  B08QLWTC2M
# 1999   75569  B0998XMCQQ
# 1999   95168  B0C2VL26VV
#
# [97718 rows x 2 columns]

# %%
rating_df.iloc[:10].to_json(orient="records")
# Out:
# '[{"item_id":556,"parent_asin":"B00006HVLW"},{"item_id":843,"parent_asin":"B00009R6NZ"},{"item_id":1039,"parent_asin":"B0000BZL05"},{"item_id":3865,"parent_asin":"B000SAKX90"},{"item_id":4646,"parent_asin":"B00139XOCI"},{"item_id":5132,"parent_asin":"B001940MFO"},{"item_id":5314,"parent_asin":"B001BDP956"},{"item_id":5780,"parent_asin":"B001GWCC4I"},{"item_id":7633,"parent_asin":"B002N4K6J6"},{"item_id":8141,"parent_asin":"B002VPE1WK"}]'

# %%
meta_df = pd.merge(rating_df, meta_df, how="inner", on="parent_asin")
meta_df
# Out:
#       item_id parent_asin                                              title  \
# 0         556  B00006HVLW  Belkin Cord Concealer with Double-Sided Adhesi...
# 1         843  B00009R6NZ  Manfrotto 700RC2 Mini Video Head wit RC2 Rapid...
# 2        1039  B0000BZL05           Avenger C1000 Drop-Ceiling Scissor Clamp
# 3        3865  B000SAKX90          Giottos MH652 Quick Release Plate (Black)
# 4        4646  B00139XOCI        Ravelli Video Tripod (67 inch Professional)
# ...       ...         ...                                                ...
# 97713   60182  B07S4BKMZV  Lenovo Flex 14 2-in-1 Convertible Laptop, 14 I...
# 97714   60806  B07TBGVLBH       Pioneer VSX-LX504 9.2-ch Network AV Receiver
# 97715   71289  B08QLWTC2M  Definitive Technology ProCenter 2000 Compact C...
# 97716   75569  B0998XMCQQ  Rolling Backpack for Kids 18 Inch , NEW TILAMI...
# 97717   95168  B0C2VL26VV  ele ELEOPTION 4G Smart Watch for Kids, IP67 Wa...
#
#                                               categories  \
# 0      [Electronics, Accessories & Supplies, Cord Man...
# 1      [Electronics, Camera & Photo, Tripods & Monopo...
# 2      [Electronics, Camera & Photo, Lighting & Studi...
# 3      [Electronics, Camera & Photo, Accessories, Tri...
# 4      [Electronics, Camera & Photo, Tripods & Monopo...
# ...                                                  ...
# 97713  [Electronics, Computers & Accessories, Compute...
# 97714  [Electronics, Home Audio, Home Theater, Receiv...
# 97715  [Electronics, Home Audio, Speakers, Center-Cha...
# 97716  [Electronics, Computers & Accessories, Laptop ...
# 97717   [Electronics, Wearable Technology, Smartwatches]
#
#               main_category  average_rating  \
# 0           All Electronics             3.9
# 1            Camera & Photo             4.2
# 2            Camera & Photo             4.5
# 3            Camera & Photo             3.5
# 4            Camera & Photo             4.1
# ...                     ...             ...
# 97713             Computers             4.2
# 97714       All Electronics             3.9
# 97715  Home Audio & Theater             4.7
# 97716        AMAZON FASHION             4.7
# 97717       All Electronics             3.2
#
#                                              description  \
# 0      [Hide unsightly computer cables easily and eff...
# 1      [Replaces the 3160XL Fluid Head, Smooth and co...
# 2      [This clamp is designed to mount small fixture...
# 3      [Giottos MH652 Quick Release Adapter with MH64...
# 4      [The Ravelli AVT is a solid tripod for camera ...
# ...                                                  ...
# 97713  [Meet the Lenovo flex 14, a stylishly compact ...
# 97714  [The Elite vsx-lx504 creates the soundscape of...
# 97715  [Product Description, The compact and versatil...
# 97716                                                 []
# 97717                                                 []
#
#                                                   images  price  rating_number
# 0      {'hi_res': ['https://m.media-amazon.com/images...   9.99           1669
# 1      {'hi_res': ['https://m.media-amazon.com/images...   None            144
# 2      {'hi_res': [None], 'large': ['https://m.media-...   None            128
# 3      {'hi_res': [None], 'large': ['https://m.media-...   None             35
# 4      {'hi_res': ['https://m.media-amazon.com/images...   None            833
# ...                                                  ...    ...            ...
# 97713  {'hi_res': ['https://m.media-amazon.com/images...   None             57
# 97714  {'hi_res': ['https://m.media-amazon.com/images...   None             34
# 97715  {'hi_res': ['https://m.media-amazon.com/images...  379.0            192
# 97716  {'hi_res': ['https://m.media-amazon.com/images...  57.39             89
# 97717  {'hi_res': ['https://m.media-amazon.com/images...  79.99            166
#
# [97718 rows x 10 columns]

# %%
meta_df = meta_df.sort_values("rating_number", ascending=False)
meta_df
# Out:
#       item_id parent_asin                                              title  \
# 5832    55461  B07H65KP63  Echo Dot (3rd Gen, 2018 release) - Smart speak...
# 128     55300  B07GZFM1ZM  Fire TV Stick 4K streaming device with Alexa V...
# 2292    58841  B07PXGQC1Q  Apple AirPods (2nd Generation) Wireless Earbud...
# 7154    68331  B08F1P3BCC  Echo Dot (4th Gen) | Smart speaker with Alexa ...
# 132     56924  B07KTYJ769  Amazon Smart Plug, for home automation, Works ...
# ...       ...         ...                                                ...
# 34385   64034  B0822S9RX4    IBM Boldface PS Cartridge Printwheel ll 1353504
# 10320   89610  B0BLP7P9DN  Jabra Evolve 65 SE Mono Wireless Headset - Blu...
# 18565   54114  B07F3KN83F  TIEGEM USB Type C 3.1 Gen 2 Cable (100W/10Gbps...
# 87608   81445  B09XR1BND4  Replacement Shoulder Pad for Camera,Backpack,M...
# 38963   52823  B07CH2D8C8                             Metal Hatch Table Lamp
#
#                                               categories  \
# 5832                                                  []
# 128                                                   []
# 2292                                                  []
# 7154                                                  []
# 132                                                   []
# ...                                                  ...
# 34385             [Electronics, Computers & Accessories]
# 10320  [Electronics, Headphones, Earbuds & Accessorie...
# 18565  [Electronics, Computers & Accessories, Compute...
# 87608  [Electronics, Computers & Accessories, Laptop ...
# 38963  [Electronics, Computers & Accessories, Compute...
#
#                    main_category  average_rating  \
# 5832              Amazon Devices             4.7
# 128               Amazon Devices             4.7
# 2292              Apple Products             4.7
# 7154              Amazon Devices             4.7
# 132               Amazon Devices             4.7
# ...                          ...             ...
# 34385            Office Products             5.0
# 10320  Cell Phones & Accessories             2.0
# 18565    Industrial & Scientific             5.0
# 87608             AMAZON FASHION             3.0
# 38963    Industrial & Scientific             5.0
#
#                                              description  \
# 5832                                                  []
# 128                                                   []
# 2292                                                  []
# 7154                                                  []
# 132                                                   []
# ...                                                  ...
# 34385                                   [|SS-TW-PW-FBM|]
# 10320  [Jabra Evolve 65 SE keeps you focused on your ...
# 18565                                                 []
# 87608  [Shoulder pad replacement apply to duffel bags...
# 38963  [Modern meets vintage in this fantastic lighti...
#
#                                                   images  price  rating_number
# 5832   {'hi_res': ['https://m.media-amazon.com/images...   None        1034896
# 128    {'hi_res': ['https://m.media-amazon.com/images...   None         819630
# 2292   {'hi_res': ['https://m.media-amazon.com/images...   99.0         585624
# 7154   {'hi_res': ['https://m.media-amazon.com/images...   None         584328
# 132    {'hi_res': ['https://m.media-amazon.com/images...  24.99         542825
# ...                                                  ...    ...            ...
# 34385  {'hi_res': ['https://m.media-amazon.com/images...  99.99              1
# 10320  {'hi_res': ['https://m.media-amazon.com/images...  156.8              1
# 18565  {'hi_res': ['https://m.media-amazon.com/images...   None              1
# 87608  {'hi_res': ['https://m.media-amazon.com/images...   9.89              1
# 38963  {'hi_res': ['https://m.media-amazon.com/images...   None              1
#
# [97718 rows x 10 columns]

# %%
meta_df.to_pickle("../../data/processed/item_meta.pkl")
